# %%
using Primes

# %%
P = primes(20)
# Out:
# 8-element Array{Int64,1}:
#   2
#   3
#   5
#   7
#  11
#  13
#  17
#  19

# %%
for p in P
    for a in 1:20
        if a % p > 0
            r = p - 1
            s = big(a)^r
            println("(a, p) = ($(a), $(p)); $(a)^$(r) = $(s); $s % $p = $(s%p)")
        end
    end
end
# Out:
# (a, p) = (1, 2); 1^1 = 1; 1 % 2 = 1
# (a, p) = (3, 2); 3^1 = 3; 3 % 2 = 1
# (a, p) = (5, 2); 5^1 = 5; 5 % 2 = 1
# (a, p) = (7, 2); 7^1 = 7; 7 % 2 = 1
# (a, p) = (9, 2); 9^1 = 9; 9 % 2 = 1
# (a, p) = (11, 2); 11^1 = 11; 11 % 2 = 1
# (a, p) = (13, 2); 13^1 = 13; 13 % 2 = 1
# (a, p) = (15, 2); 15^1 = 15; 15 % 2 = 1
# (a, p) = (17, 2); 17^1 = 17; 17 % 2 = 1
# (a, p) = (19, 2); 19^1 = 19; 19 % 2 = 1
# (a, p) = (1, 3); 1^2 = 1; 1 % 3 = 1
# (a, p) = (2, 3); 2^2 = 4; 4 % 3 = 1
# (a, p) = (4, 3); 4^2 = 16; 16 % 3 = 1
# (a, p) = (5, 3); 5^2 = 25; 25 % 3 = 1
# (a, p) = (7, 3); 7^2 = 49; 49 % 3 = 1
# (a, p) = (8, 3); 8^2 = 64; 64 % 3 = 1
# (a, p) = (10, 3); 10^2 = 100; 100 % 3 = 1
# (a, p) = (11, 3); 11^2 = 121; 121 % 3 = 1
# (a, p) = (13, 3); 13^2 = 169; 169 % 3 = 1
# (a, p) = (14, 3); 14^2 = 196; 196 % 3 = 1
# (a, p) = (16, 3); 16^2 = 256; 256 % 3 = 1
# (a, p) = (17, 3); 17^2 = 289; 289 % 3 = 1
# (a, p) = (19, 3); 19^2 = 361; 361 % 3 = 1
# (a, p) = (20, 3); 20^2 = 400; 400 % 3 = 1
# ...
